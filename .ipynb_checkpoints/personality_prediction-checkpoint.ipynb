# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 200

# Show all columns
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df = pd.read_csv('data/data.csv', sep=';', index_col=0)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 137 entries, 1 to 137
# Data columns (total 94 columns):
# ID                               137 non-null int64
# Gender                           137 non-null int64
# Age                              137 non-null int64
# Education_lev                    137 non-null int64
# fluidIQ                          137 non-null object
# Emotional.Stability..N.          137 non-null object
# Carefreeness..N1.                137 non-null object
# Equanimity..N2.                  137 non-null object
# Positive.mood..N3.               137 non-null object
# Self.consciousness..N4.          137 non-null object
# Self.control..N5.                137 non-null object
# Emot..robustness..N6.            137 non-null object
# Extraversion..E.                 137 non-null object
# Friendliness..E1.                137 non-null object
# Sociableness..E2.                137 non-null object
# Assertiveness..E3.               137 non-null object
# Dynamism..E4.                    137 non-null object
# Adventurousness...E5.            137 non-null object
# Cheerfulness..E6.                137 non-null object
# Openness..O.                     137 non-null object
# Openn..to.imagin...O1.           137 non-null object
# Openn..to.aesth...O2.            137 non-null object
# Openn..to.feel...O3.             137 non-null object
# Openn..to.actions..O4.           137 non-null object
# Openn..to.ideas..O5.             137 non-null object
# Openn..to.val..norm...O6.        137 non-null object
# Conscientiousness..C.            137 non-null object
# Competence..C1.                  137 non-null object
# Love.of.order..C2.               137 non-null object
# Sense.of.duty..C3.               137 non-null object
# Ambition..C4.                    137 non-null object
# Discipline..C5.                  137 non-null object
# Caution..C6.                     137 non-null object
# Agreeableness..A.                137 non-null object
# Willingness.to.trust..A1.        137 non-null object
# Genuineness..A2.                 137 non-null object
# Helpfulness..A3.                 137 non-null object
# Obligingness..A4.                137 non-null object
# Modesty..A5.                     137 non-null object
# Good.naturedness..A6.            137 non-null object
# freq_calls                       137 non-null int64
# freq_Tools                       137 non-null int64
# freq_Finance                     137 non-null int64
# freq_Games                       137 non-null int64
# freq_Entertainment               137 non-null int64
# freq_Productivity                137 non-null int64
# freq_Personalization             137 non-null int64
# freq_News...Magazines            137 non-null int64
# freq_Unknown                     137 non-null int64
# freq_Photography                 137 non-null int64
# freq_Shopping                    137 non-null int64
# freq_Communication               137 non-null int64
# freq_Books...Reference           137 non-null int64
# freq_Travel...Local              137 non-null int64
# freq_Music...Audio               137 non-null int64
# freq_Medical                     137 non-null int64
# freq_Education                   137 non-null int64
# freq_Business                    137 non-null int64
# freq_Lifestyle                   137 non-null int64
# freq_Transportation              137 non-null int64
# freq_Weather                     137 non-null int64
# freq_Sports                      137 non-null int64
# freq_Browser                     137 non-null int64
# freq_Health...Fitness            137 non-null int64
# freq_Media...Video               137 non-null int64
# freq_Social                      137 non-null int64
# freq_Comics                      137 non-null int64
# mydatatest.avg_duration_calls    137 non-null object
# dur_Tools                        137 non-null object
# dur_Finance                      137 non-null object
# dur_Games                        137 non-null object
# dur_Entertainment                137 non-null object
# dur_Productivity                 137 non-null object
# dur_Personalization              137 non-null object
# dur_News...Magazines             137 non-null object
# dur_Unknown                      137 non-null object
# dur_Photography                  137 non-null object
# dur_Shopping                     137 non-null object
# dur_Communication                137 non-null object
# dur_Books...Reference            137 non-null object
# dur_Travel...Local               137 non-null object
# dur_Music...Audio                137 non-null object
# dur_Medical                      137 non-null object
# dur_Education                    137 non-null object
# dur_Business                     137 non-null object
# dur_Lifestyle                    137 non-null object
# dur_Transportation               137 non-null object
# dur_Weather                      137 non-null object
# dur_Sports                       137 non-null object
# dur_Browser                      137 non-null object
# dur_Health...Fitness             137 non-null object
# dur_Media...Video                137 non-null object
# dur_Social                       137 non-null object
# dur_Comics                       137 non-null object
# dtypes: int64(31), object(63)
# memory usage: 101.7+ KB
# None

# %%
# Convert to float (pandas detect point as the separator for floats instead of comma)
for column_index in range(0,len(df.columns)):
    name = df.columns[column_index]
    if df[name].dtype == np.object:
        df[name] = df[name].str.replace(',', '.').astype(float)

# %%
df.shape
# Out:
# (137, 94)

# %%
df.head(10)
# Out:
#        ID  Gender  Age  Education_lev  fluidIQ  Emotional.Stability..N.  \
# 1   11304       1   23              4   0.7251                  -0.9334
# 2   11491       1   21              4   0.9921                   1.1622
# 3   12552       2   22              5   0.5541                  -1.6827
# 4   13275       2   34              5   0.7387                  -0.9873
# 5   13604       2   23              4   0.9785                   0.1927
# 6   14154       1   25              5   0.2092                   0.5203
# 7   15693       1   23              5   0.4192                  -1.4149
# 8   17399       2   18              4   0.5361                  -0.8745
# 9   18336       2   20              4   0.2676                  -0.3583
# 10  18818       2   21              4   0.2590                   0.7022
#
#     Carefreeness..N1.  Equanimity..N2.  Positive.mood..N3.  \
# 1              -1.230           -0.357              -0.720
# 2               0.993            2.520               1.323
# 3              -2.016           -2.303              -2.371
# 4              -0.470           -0.580              -0.190
# 5               0.510            0.696               1.079
# 6               0.510            1.311               1.323
# 7              -2.583           -0.580              -2.687
# 8              -1.488           -1.274               0.072
# 9              -0.470            0.075               0.331
# 10              2.261            2.236               2.073
#
#     Self.consciousness..N4.  Self.control..N5.  Emot..robustness..N6.  \
# 1                    -0.335              0.110                 -0.688
# 2                     0.562              1.799                  5.526
# 3                     0.562             -1.045                 -1.484
# 4                    -0.815             -0.334                 -0.430
# 5                     1.410              0.533                  1.020
# 6                     1.199              1.575                  1.994
# 7                    -1.316              0.533                  0.071
# 8                     1.199             -0.109                 -0.951
# 9                     0.988              0.739                 -0.430
# 10                    2.072             -1.821                  1.255
#
#     Extraversion..E.  Friendliness..E1.  Sociableness..E2.  \
# 1            -1.0278             -1.068              0.247
# 2            -1.1607             -1.488             -1.798
# 3            -0.2877              0.082              2.391
# 4            -0.8691              1.370             -0.749
# 5             0.3674              0.850              2.692
# 6            -0.1213              0.082              1.018
# 7            -0.9906              0.850             -1.261
# 8             0.5066              2.472              2.692
# 9            -0.0090              1.110              1.553
# 10            0.4861              2.472              1.826
#
#     Assertiveness..E3.  Dynamism..E4.  Adventurousness...E5.  \
# 1                1.235         -0.359                 -1.081
# 2                2.043         -1.182                  0.554
# 3               -2.005          2.375                  1.438
# 4                0.228         -1.182                  0.107
# 5                1.767          3.312                  0.995
# 6                2.043          0.837                  1.215
# 7               -0.013         -1.182                 -1.882
# 8                1.767          2.375                  2.151
# 9                1.498          1.777                 -0.354
# 10               0.473          2.375                  2.419
#
#     Cheerfulness..E6.  Openness..O.  Openn..to.imagin...O1.  \
# 1              -1.438       -1.0703                   0.576
# 2              -1.222        0.1221                   1.558
# 3              -0.309        0.1810                   1.058
# 4              -0.309       -0.4643                   0.343
# 5               0.840       -0.3404                   0.815
# 6               1.172       -0.3014                  -0.748
# 7               0.840       -0.5096                   1.058
# 8               0.840       -0.0279                   2.381
# 9               1.172       -0.1844                   1.818
# 10              2.187        0.0551                   0.343
#
#     Openn..to.aesth...O2.  Openn..to.feel...O3.  Openn..to.actions..O4.  \
# 1                  -0.475                -0.517                  -0.563
# 2                  -0.475                -5.648                   0.917
# 3                   0.288                 0.284                   2.849
# 4                  -0.018                 1.280                   1.180
# 5                  -0.475                 0.001                   0.401
# 6                  -0.795                -1.235                   2.248
# 7                   0.444                 0.591                  -0.563
# 8                   0.773                 4.838                   0.401
# 9                   0.444                 3.368                   0.657
# 10                 -0.475                 1.280                   4.237
#
#     Openn..to.ideas..O5.  Openn..to.val..norm...O6.  Conscientiousness..C.  \
# 1                  1.290                     -1.608                -0.8548
# 2                  5.515                      1.332                 1.0258
# 3                  2.513                      0.940                -1.1241
# 4                  1.003                      0.568                -1.4071
# 5                  2.193                      0.940                 0.1243
# 6                  2.854                      0.753                 0.5660
# 7                  2.193                     -0.186                 0.4900
# 8                  1.290                      0.197                 0.7585
# 9                  1.003                      0.384                -0.0150
# 10                 0.727                      1.332                -1.4056
#
#     Competence..C1.  Love.of.order..C2.  Sense.of.duty..C3.  Ambition..C4.  \
# 1            -0.236               1.687              -0.828          0.341
# 2             4.435               0.905               2.401          4.040
# 3            -1.872              -0.732               1.782          0.936
# 4            -0.651              -0.958              -0.430         -1.159
# 5             0.722               2.251               2.401          2.539
# 6             1.889               2.559               2.401          3.586
# 7            -0.236               3.765               3.144          2.221
# 8             2.541               3.765               2.749          3.586
# 9             1.285               1.160               2.401          1.255
# 10           -0.447              -2.214              -0.430          0.630
#
#     Discipline..C5.  Caution..C6.  Agreeableness..A.  \
# 1             0.020         0.834            -1.4482
# 2             4.552         2.401            -2.1099
# 3            -0.227        -1.114            -0.1796
# 4            -0.227        -0.226            -0.8839
# 5             1.816         1.139            -0.6329
# 6             2.769         1.768            -0.9829
# 7             2.132         3.455            -1.2005
# 8             1.816         2.726            -0.8064
# 9             1.496         1.768            -0.0711
# 10           -0.691        -0.899             0.7732
#
#     Willingness.to.trust..A1.  Genuineness..A2.  Helpfulness..A3.  \
# 1                      -0.032             0.154            -0.764
# 2                      -1.156            -0.562            -2.474
# 3                       1.875             3.585             0.471
# 4                       0.653             0.615            -0.059
# 5                       0.194             0.615             0.471
# 6                      -1.156             0.862            -0.059
# 7                      -0.481            -0.562             0.753
# 8                      -2.413             0.615             0.200
# 9                       0.886             1.394             1.997
# 10                      2.767             2.684             2.343
#
#     Obligingness..A4.  Modesty..A5.  Good.naturedness..A6.  freq_calls  \
# 1              -1.027        -1.082                 -0.788         120
# 2              -0.404        -1.082                 -2.993          98
# 3              -0.616         2.202                 -0.264         226
# 4              -0.186         0.093                  0.389          89
# 5               0.041         1.419                  0.389         244
# 6              -0.616         0.516                  0.042         244
# 7              -1.027        -1.884                  0.785          47
# 8               0.277        -1.884                  2.861         368
# 9               0.277         0.302                  2.094         129
# 10              1.322         1.923                  3.611          37
#
#     freq_Tools  freq_Finance  freq_Games  freq_Entertainment  \
# 1          414             0          40                  51
# 2          239             3           0                  21
# 3          135             0         347                   6
# 4          157             0           0                  41
# 5          140             0         164                  20
# 6           44             0           3                   4
# 7          459             0           9                 135
# 8          926             0         121                 508
# 9          493            84           2                  94
# 10         204             0         387                  23
#
#     freq_Productivity  freq_Personalization  freq_News...Magazines  \
# 1                 553                     0                      8
# 2                  88                     0                      4
# 3                  75                     0                      9
# 4                  75                     2                      4
# 5                 140                     1                      0
# 6                  29                     0                      4
# 7                 447                     0                     10
# 8                 202                     0                      7
# 9                 228                    20                     24
# 10                269                     0                     84
#
#     freq_Unknown  freq_Photography  freq_Shopping  freq_Communication  \
# 1             31               260             52                1930
# 2             42               113             23                3430
# 3              6                40             19                1068
# 4           3625               102              0                3140
# 5           3284               266              0                2153
# 6              8                 5              0                 716
# 7             33               134              0                1433
# 8             34               443              3                6019
# 9            240               635              1                4575
# 10            19               126             91                2086
#
#     freq_Books...Reference  freq_Travel...Local  freq_Music...Audio  \
# 1                        3                  128                 113
# 2                        5                   19                   4
# 3                       12                   20                   2
# 4                      256                  108                  21
# 5                       14                  141                  13
# 6                        2                   23                  27
# 7                       24                   84                  12
# 8                       12                  192                 183
# 9                       25                   33                  27
# 10                      17                   21                  15
#
#     freq_Medical  freq_Education  freq_Business  freq_Lifestyle  \
# 1              0              11              1               7
# 2              0               0              7               0
# 3              0              69              3               0
# 4              0               0              9               0
# 5              0               0              0               0
# 6              0               0              1               0
# 7              0              37             51               0
# 8             45              28             23               1
# 9              0               2             39               4
# 10            75               0             11               7
#
#     freq_Transportation  freq_Weather  freq_Sports  freq_Browser  \
# 1                   153             0          184           231
# 2                    34             0            0           187
# 3                    47             0            0           101
# 4                     3           108            0           263
# 5                     6            72            0           363
# 6                     0             3            0           166
# 7                    53            29            0           104
# 8                     0            60            0           624
# 9                    21            13            0          1494
# 10                  316             2            0           446
#
#     freq_Health...Fitness  freq_Media...Video  freq_Social  freq_Comics  \
# 1                     176                   1            8            0
# 2                       0                   1          211            0
# 3                       0                   0          277            0
# 4                      53                   4          118            0
# 5                       0                  10           15            0
# 6                       2                   0            2            0
# 7                      14                  28          308            0
# 8                      47                  27         1344            0
# 9                       0                  39          365            0
# 10                      6                  14           95            0
#
#     mydatatest.avg_duration_calls  dur_Tools  dur_Finance   dur_Games  \
# 1                       80.508333  19.989234     0.000000  474.149741
# 2                      176.214286  21.201236    77.000000    0.000000
# 3                       84.902655  27.019119     0.000000  178.964202
# 4                       35.314607  20.677723     0.000000    0.000000
# 5                       98.163934   8.812732     0.000000   43.500911
# 6                      149.479508  12.009685     0.000000  563.000000
# 7                      684.212766  10.140074     0.000000   19.168038
# 8                       31.777174  16.143545     0.000000  183.087773
# 9                        0.000000   6.182718    36.319479  207.000000
# 10                     241.864865   9.991116     0.000000  366.901522
#
#     dur_Entertainment  dur_Productivity  dur_Personalization  \
# 1           66.142812         27.299807             0.000000
# 2          292.695366         29.823646             0.000000
# 3            0.000000         32.312866             0.000000
# 4           84.173028         31.069522            99.000000
# 5            3.621455         14.409825             6.000000
# 6            0.000000         16.812789             0.000000
# 7           19.190880         14.409578             0.000000
# 8          182.977181         12.091483             0.000000
# 9           77.823472         18.905723             1.209473
# 10          18.606738         15.442635             0.000000
#
#     dur_News...Magazines  dur_Unknown  dur_Photography  dur_Shopping  \
# 1              63.482948     5.594866        22.306456     62.541808
# 2               0.000000     2.149066        16.753147     90.804380
# 3              95.700334     5.062647        38.577362     39.389153
# 4               0.000000     3.227029        17.030655      0.000000
# 5               0.000000     2.502265        11.132798      0.000000
# 6               0.000000     5.079446        87.795246      0.000000
# 7               6.392009     3.818803        13.752979      0.000000
# 8               8.250000     2.000000        23.757153      0.000000
# 9               2.000000     3.091656        20.498183      6.000000
# 10             79.574810     3.507751        24.261084    115.493502
#
#     dur_Communication  dur_Books...Reference  dur_Travel...Local  \
# 1           60.222363             102.000000           66.640780
# 2           42.197411              52.000000           53.702947
# 3           25.361692              35.660060          149.456141
# 4           41.059489              30.193285           42.857908
# 5           26.968565              67.712688           48.223207
# 6           18.378426               0.000000           28.403840
# 7           21.941385               3.326674           17.310039
# 8           29.532116              10.990015           37.443360
# 9           33.956120              29.714029           61.946773
# 10          37.603151              47.040050           33.571429
#
#     dur_Music...Audio  dur_Medical  dur_Education  dur_Business  \
# 1           19.273367     0.000000      35.316076      4.000000
# 2            0.000000     0.000000       0.000000     24.285714
# 3           20.000000     0.000000     239.753781      3.666667
# 4           15.253427     0.000000       0.000000     11.405742
# 5            2.245006     0.000000       0.000000      0.000000
# 6            9.307286     0.000000       0.000000     30.000000
# 7            3.995560     0.000000      20.625025      5.435565
# 8           21.063829     2.000000      50.881585     23.950056
# 9            8.087628     0.000000       0.000000     46.117719
# 10          71.181818     7.461809       0.000000     20.455053
#
#     dur_Lifestyle  dur_Transportation  dur_Weather  dur_Sports  dur_Browser  \
# 1       60.666667           55.469027     0.000000  124.447371    72.502856
# 2        0.000000           74.587645     0.000000    0.000000    95.829110
# 3        0.000000           65.977454     0.000000    0.000000    86.099052
# 4        0.000000            2.000000    28.180582    0.000000    50.146309
# 5        0.000000           77.333333     3.812671    0.000000    30.335529
# 6        0.000000            0.000000    36.039955    0.000000   138.688685
# 7        0.000000           20.769756     2.000000    0.000000    33.798318
# 8        0.000000            0.000000     3.667833    0.000000    38.178520
# 9        0.000000           57.800000     2.000000    0.000000    59.671803
# 10      28.935072           50.761661     0.000000    0.000000    53.722716
#
#     dur_Health...Fitness  dur_Media...Video  dur_Social  dur_Comics
# 1             125.382997         140.000000    0.000000         0.0
# 2               0.000000           0.000000   82.581954         0.0
# 3               0.000000           0.000000   78.253432         0.0
# 4              37.600068           0.000000   63.630655         0.0
# 5               0.000000           9.000000   16.400009         0.0
# 6             157.000000           0.000000    0.000000         0.0
# 7              18.473355          20.486991   22.693596         0.0
# 8              25.639536          43.182417   48.548519         0.0
# 9               0.000000          17.589697   65.207059         0.0
# 10             65.865155          12.091134   34.765156         0.0

# %%
df.describe()
# Out:
#                  ID      Gender         Age  Education_lev     fluidIQ  \
# count    137.000000  137.000000  137.000000     137.000000  137.000000
# mean   54616.875912    1.635036   23.576642       4.262774    0.631851
# std    26706.681117    0.483187    4.713439       0.572277    0.635674
# min    11304.000000    1.000000   18.000000       2.000000   -0.966100
# 25%    32670.000000    1.000000   20.000000       4.000000    0.209200
# 50%    49459.000000    2.000000   23.000000       4.000000    0.624300
# 75%    78794.000000    2.000000   26.000000       5.000000    0.954700
# max    99007.000000    2.000000   50.000000       5.000000    3.094600
#
#        Emotional.Stability..N.  Carefreeness..N1.  Equanimity..N2.  \
# count               137.000000         137.000000       137.000000
# mean                 -0.042369           0.030613         0.484299
# std                   0.704431           1.181586         1.025598
# min                  -1.995500          -2.583000        -2.303000
# 25%                  -0.420000          -0.721000        -0.139000
# 50%                  -0.047500           0.024000         0.492000
# 75%                   0.430300           0.752000         1.311000
# max                   2.520100           3.236000         3.266000
#
#        Positive.mood..N3.  Self.consciousness..N4.  Self.control..N5.  \
# count          137.000000               137.000000         137.000000
# mean             0.917080                 0.718314           0.703993
# std              1.441432                 1.110192           1.009195
# min             -4.553000                -2.421000          -2.101000
# 25%              0.331000                 0.123000           0.110000
# 50%              1.079000                 0.988000           0.739000
# 75%              1.817000                 1.410000           1.360000
# max              5.595000                 3.896000           3.357000
#
#        Emot..robustness..N6.  Extraversion..E.  Friendliness..E1.  \
# count             137.000000        137.000000         137.000000
# mean                0.675029          0.028110           1.424715
# std                 1.266313          0.738225           1.330950
# min                -1.755000         -1.976000          -1.698000
# 25%                -0.177000         -0.462800           0.850000
# 50%                 0.551000         -0.000700           1.370000
# 75%                 1.255000          0.486100           2.472000
# max                 5.526000          1.876400           5.413000
#
#        Sociableness..E2.  Assertiveness..E3.  Dynamism..E4.  \
# count         137.000000          137.000000     137.000000
# mean            1.348635            0.794533       1.373861
# std             1.724559            1.422916       1.515672
# min            -3.407000           -2.297000      -2.017000
# 25%             0.247000           -0.252000       0.523000
# 50%             1.553000            0.722000       1.469000
# 75%             2.391000            1.767000       2.375000
# max             5.644000            5.613000       5.940000
#
#        Adventurousness...E5.  Cheerfulness..E6.  Openness..O.  \
# count             137.000000         137.000000    137.000000
# mean                0.438277           1.818153      0.014118
# std                 1.563366           1.658103      0.719639
# min                -3.249000          -3.233000     -1.841000
# 25%                -0.590000           0.840000     -0.496600
# 50%                 0.554000           1.850000     -0.112800
# 75%                 1.215000           2.877000      0.441600
# max                 5.270000           6.088000      2.117600
#
#        Openn..to.imagin...O1.  Openn..to.aesth...O2.  Openn..to.feel...O3.  \
# count              137.000000             137.000000            137.000000
# mean                 1.295854               0.338891              2.098730
# std                  1.450106               1.205096              2.233198
# min                 -2.043000              -2.376000             -5.648000
# 25%                  0.343000              -0.475000              0.591000
# 50%                  1.058000               0.134000              2.001000
# 75%                  2.090000               0.949000              3.368000
# max                  5.329000               4.610000              6.041000
#
#        Openn..to.actions..O4.  Openn..to.ideas..O5.  \
# count              137.000000            137.000000
# mean                 1.505277              1.882343
# std                  1.405276              1.438068
# min                 -2.745000             -0.853000
# 25%                  0.657000              0.727000
# 50%                  1.443000              1.584000
# 75%                  2.248000              2.854000
# max                  5.419000              5.515000
#
#        Openn..to.val..norm...O6.  Conscientiousness..C.  Competence..C1.  \
# count                 137.000000             137.000000       137.000000
# mean                    0.930080               0.078236         1.047380
# std                     1.040225               0.771432         1.300464
# min                    -1.608000              -1.625900        -1.872000
# 25%                     0.197000              -0.433400         0.216000
# 50%                     0.753000               0.059000         0.997000
# 75%                     1.332000               0.601800         1.889000
# max                     4.863000               1.814300         4.435000
#
#        Love.of.order..C2.  Sense.of.duty..C3.  Ambition..C4.  Discipline..C5.  \
# count          137.000000          137.000000     137.000000       137.000000
# mean             1.211854            2.204343       2.202387         1.773051
# std              1.627545            1.456822       1.623771         1.533370
# min             -4.340000           -1.593000      -1.395000        -1.132000
# 25%              0.176000            1.220000       1.255000         0.563000
# 50%              1.160000            2.401000       1.902000         1.816000
# 75%              2.251000            3.144000       3.206000         2.447000
# max              5.669000            5.504000       5.857000         5.747000
#
#        Caution..C6.  Agreeableness..A.  Willingness.to.trust..A1.  \
# count    137.000000         137.000000                 137.000000
# mean       1.776854          -0.155520                   0.232226
# std        1.418070           0.751646                   1.320063
# min       -1.330000          -2.109900                  -3.086000
# 25%        0.834000          -0.632900                  -0.481000
# 50%        1.768000          -0.189000                   0.194000
# 75%        2.726000           0.282200                   1.123000
# max        5.747000           1.800900                   4.211000
#
#        Genuineness..A2.  Helpfulness..A3.  Obligingness..A4.  Modesty..A5.  \
# count        137.000000        137.000000         137.000000    137.000000
# mean           0.997241          1.595482           0.887182      0.581350
# std            0.906695          1.461493           1.146615      1.182267
# min           -1.204000         -2.474000          -1.864000     -2.682000
# 25%            0.379000          0.753000           0.041000     -0.112000
# 50%            0.862000          1.667000           0.779000      0.516000
# 75%            1.394000          2.343000           1.606000      1.184000
# max            4.246000          6.045000           3.705000      3.913000
#
#        Good.naturedness..A6.   freq_calls   freq_Tools  freq_Finance  \
# count             137.000000   137.000000   137.000000    137.000000
# mean                1.914555   248.408759   441.299270     13.328467
# std                 1.728174   244.286553   629.903113     45.270772
# min                -2.993000    13.000000     4.000000      0.000000
# 25%                 0.785000    90.000000   147.000000      0.000000
# 50%                 1.670000   170.000000   238.000000      0.000000
# 75%                 2.861000   312.000000   393.000000      3.000000
# max                 6.402000  1300.000000  3859.000000    359.000000
#
#         freq_Games  freq_Entertainment  freq_Productivity  \
# count   137.000000          137.000000         137.000000
# mean    151.430657           64.985401         207.175182
# std     323.370503           87.400110         252.677308
# min       0.000000            0.000000           7.000000
# 25%       0.000000           13.000000          64.000000
# 50%      29.000000           32.000000         120.000000
# 75%     164.000000           76.000000         254.000000
# max    2893.000000          508.000000        1761.000000
#
#        freq_Personalization  freq_News...Magazines  freq_Unknown  \
# count            137.000000             137.000000    137.000000
# mean               2.051095              49.087591    378.284672
# std                7.243984             104.146706   1048.512027
# min                0.000000               0.000000      1.000000
# 25%                0.000000               4.000000     15.000000
# 50%                0.000000              12.000000     33.000000
# 75%                0.000000              51.000000     92.000000
# max               65.000000             915.000000   7794.000000
#
#        freq_Photography  freq_Shopping  freq_Communication  \
# count        137.000000     137.000000          137.000000
# mean         161.197080      18.138686         2309.094891
# std          193.820598      55.378004         1552.277676
# min            2.000000       0.000000          223.000000
# 25%           56.000000       0.000000         1286.000000
# 50%          113.000000       0.000000         1874.000000
# 75%          194.000000      17.000000         2775.000000
# max         1316.000000     512.000000         8357.000000
#
#        freq_Books...Reference  freq_Travel...Local  freq_Music...Audio  \
# count              137.000000           137.000000          137.000000
# mean                35.080292            60.335766           83.729927
# std                105.399385            60.853159          115.314564
# min                  0.000000             0.000000            0.000000
# 25%                  4.000000            20.000000           13.000000
# 50%                  8.000000            42.000000           37.000000
# 75%                 24.000000            84.000000          104.000000
# max                976.000000           341.000000          673.000000
#
#        freq_Medical  freq_Education  freq_Business  freq_Lifestyle  \
# count    137.000000      137.000000     137.000000      137.000000
# mean       6.197080       13.262774      16.846715       35.109489
# std       28.248592       40.075713      22.369192       86.444872
# min        0.000000        0.000000       0.000000        0.000000
# 25%        0.000000        0.000000       1.000000        0.000000
# 50%        0.000000        0.000000       8.000000        2.000000
# 75%        0.000000        7.000000      23.000000       28.000000
# max      294.000000      356.000000     112.000000      700.000000
#
#        freq_Transportation  freq_Weather  freq_Sports  freq_Browser  \
# count           137.000000    137.000000   137.000000    137.000000
# mean             54.102190     16.014599    30.934307    386.532847
# std              60.929598     29.304433   211.226050    370.334548
# min               0.000000      0.000000     0.000000      0.000000
# 25%               4.000000      0.000000     0.000000    127.000000
# 50%              40.000000      1.000000     0.000000    274.000000
# 75%              74.000000     19.000000     0.000000    524.000000
# max             316.000000    197.000000  2413.000000   2448.000000
#
#        freq_Health...Fitness  freq_Media...Video  freq_Social  freq_Comics  \
# count             137.000000          137.000000   137.000000   137.000000
# mean               25.423358           19.087591   435.737226     0.262774
# std                75.146986           27.679222   652.055712     1.501323
# min                 0.000000            0.000000     0.000000     0.000000
# 25%                 0.000000            2.000000    10.000000     0.000000
# 50%                 0.000000            9.000000   170.000000     0.000000
# 75%                11.000000           23.000000   557.000000     0.000000
# max               503.000000          143.000000  3800.000000    13.000000
#
#        mydatatest.avg_duration_calls   dur_Tools  dur_Finance    dur_Games  \
# count                     137.000000  137.000000   137.000000   137.000000
# mean                      103.729555   16.541400    11.371972   153.330079
# std                       162.454391   10.744331    22.427098   196.642283
# min                         0.000000    0.000000     0.000000     0.000000
# 25%                        24.980952    9.911273     0.000000     0.000000
# 50%                        61.862832   15.625698     0.000000    89.007206
# 75%                       117.864583   21.123102     5.333333   234.750000
# max                      1347.676471   89.699323   110.300371  1148.885365
#
#        dur_Entertainment  dur_Productivity  dur_Personalization  \
# count         137.000000        137.000000           137.000000
# mean           94.005113         23.472882             4.348049
# std           108.693914         11.618183            19.079219
# min             0.000000          3.863384             0.000000
# 25%            28.000000         15.960049             0.000000
# 50%            65.851689         22.364578             0.000000
# 75%           123.014899         27.597095             0.000000
# max           800.921008        100.312420           158.220869
#
#        dur_News...Magazines  dur_Unknown  dur_Photography  dur_Shopping  \
# count            137.000000   137.000000       137.000000    137.000000
# mean              36.655824     4.363831        23.917920     33.203324
# std               51.081650     2.807209        12.810812     91.035876
# min                0.000000     1.904499         3.890978      0.000000
# 25%                0.000000     2.887218        17.170467      0.000000
# 50%                6.392009     3.527476        21.473463      0.000000
# 75%               63.482948     5.019853        27.452027     43.910100
# max              250.529055    19.461362        87.795246    929.000000
#
#        dur_Communication  dur_Books...Reference  dur_Travel...Local  \
# count         137.000000             137.000000          137.000000
# mean           31.276671              31.238918           55.909233
# std            14.116448              63.900603           29.931091
# min             5.060196               0.000000            0.000000
# 25%            21.941385               0.000000           41.066667
# 50%            30.294371              15.666667           51.340066
# 75%            37.234003              36.773295           63.110274
# max            94.208916             552.500000          231.000000
#
#        dur_Music...Audio  dur_Medical  dur_Education  dur_Business  \
# count         137.000000   137.000000     137.000000    137.000000
# mean           15.367923     2.147814      32.851426     36.405302
# std            17.534956    10.347300      90.414282     44.986550
# min             0.000000     0.000000       0.000000      0.000000
# 25%             5.374710     0.000000       0.000000      3.666667
# 50%            10.726118     0.000000       0.000000     26.315466
# 75%            19.273367     0.000000      22.278083     49.805238
# max           130.600000    88.000000     647.215582    298.910349
#
#        dur_Lifestyle  dur_Transportation  dur_Weather  dur_Sports  \
# count     137.000000          137.000000   137.000000  137.000000
# mean       24.790996           39.471704    10.653809   18.179038
# std        40.003307           25.767431    16.659067   77.427695
# min         0.000000            0.000000     0.000000    0.000000
# 25%         0.000000           21.546362     0.000000    0.000000
# 50%         0.000000           43.431086     2.000000    0.000000
# 75%        39.911442           56.000000    17.000000    0.000000
# max       207.973434          100.360241   131.000000  856.174395
#
#        dur_Browser  dur_Health...Fitness  dur_Media...Video  dur_Social  \
# count   137.000000            137.000000         137.000000  137.000000
# mean     72.152846             20.519298          38.645176   50.517572
# std      32.606484             54.878332         125.422554   47.262065
# min       0.000000              0.000000           0.000000    0.000000
# 25%      52.580801              0.000000           0.000000   16.400009
# 50%      68.159707              0.000000          11.515408   43.880126
# 75%      87.628893             24.987019          39.400000   70.695620
# max     252.813082            518.000000        1352.464837  279.483674
#
#        dur_Comics
# count  137.000000
# mean     5.332793
# std     38.013611
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max    397.000000

# %%
df_categories_freq = df.loc[:,'freq_calls':'freq_Comics'].copy()
df_categories_freq.head(3)
# Out:
#    freq_calls  freq_Tools  freq_Finance  freq_Games  freq_Entertainment  \
# 1         120         414             0          40                  51
# 2          98         239             3           0                  21
# 3         226         135             0         347                   6
#
#    freq_Productivity  freq_Personalization  freq_News...Magazines  \
# 1                553                     0                      8
# 2                 88                     0                      4
# 3                 75                     0                      9
#
#    freq_Unknown  freq_Photography  freq_Shopping  freq_Communication  \
# 1            31               260             52                1930
# 2            42               113             23                3430
# 3             6                40             19                1068
#
#    freq_Books...Reference  freq_Travel...Local  freq_Music...Audio  \
# 1                       3                  128                 113
# 2                       5                   19                   4
# 3                      12                   20                   2
#
#    freq_Medical  freq_Education  freq_Business  freq_Lifestyle  \
# 1             0              11              1               7
# 2             0               0              7               0
# 3             0              69              3               0
#
#    freq_Transportation  freq_Weather  freq_Sports  freq_Browser  \
# 1                  153             0          184           231
# 2                   34             0            0           187
# 3                   47             0            0           101
#
#    freq_Health...Fitness  freq_Media...Video  freq_Social  freq_Comics
# 1                    176                   1            8            0
# 2                      0                   1          211            0
# 3                      0                   0          277            0

# %%
df_categories_freq_mean = df_categories_freq.mean(axis = 0, skipna = True)
df_categories_freq_mean
# Out:
# freq_calls                 248.408759
# freq_Tools                 441.299270
# freq_Finance                13.328467
# freq_Games                 151.430657
# freq_Entertainment          64.985401
# freq_Productivity          207.175182
# freq_Personalization         2.051095
# freq_News...Magazines       49.087591
# freq_Unknown               378.284672
# freq_Photography           161.197080
# freq_Shopping               18.138686
# freq_Communication        2309.094891
# freq_Books...Reference      35.080292
# freq_Travel...Local         60.335766
# freq_Music...Audio          83.729927
# freq_Medical                 6.197080
# freq_Education              13.262774
# freq_Business               16.846715
# freq_Lifestyle              35.109489
# freq_Transportation         54.102190
# freq_Weather                16.014599
# freq_Sports                 30.934307
# freq_Browser               386.532847
# freq_Health...Fitness       25.423358
# freq_Media...Video          19.087591
# freq_Social                435.737226
# freq_Comics                  0.262774
# dtype: float64

# %%
labels = ['Calls','Tools','Finance','Games','Entertainment','Productivity',
          'Personalization','News & Magazines','Unknown','Photography','Shopping',
          'Communication','Books & Reference','Travel & Local','Music & Audio',
          'Medical','Education','Business','Lifestyle','Transportation','Weather','Sports',
          'Browser','Health & Fitness', 'Media & Video', 'Social', 'Comics']

ax = sns.barplot(x=df_categories_freq_mean.index, y=df_categories_freq_mean.values)
ax.set_xticklabels(rotation=90, labels=labels)
plt.xlabel("Application category")
plt.ylabel("Average number of uses")

#fig = ax.get_figure()
#plt.savefig('figures/number_of_uses_by_category', dpi=200)

plt.show(ax)

# %%
df_categories_dur = df.loc[:,'mydatatest.avg_duration_calls':'dur_Comics'].copy()
df_categories_dur.head(2)
# Out:
#    mydatatest.avg_duration_calls  dur_Tools  dur_Finance   dur_Games  \
# 1                      80.508333  19.989234          0.0  474.149741
# 2                     176.214286  21.201236         77.0    0.000000
#
#    dur_Entertainment  dur_Productivity  dur_Personalization  \
# 1          66.142812         27.299807                  0.0
# 2         292.695366         29.823646                  0.0
#
#    dur_News...Magazines  dur_Unknown  dur_Photography  dur_Shopping  \
# 1             63.482948     5.594866        22.306456     62.541808
# 2              0.000000     2.149066        16.753147     90.804380
#
#    dur_Communication  dur_Books...Reference  dur_Travel...Local  \
# 1          60.222363                  102.0           66.640780
# 2          42.197411                   52.0           53.702947
#
#    dur_Music...Audio  dur_Medical  dur_Education  dur_Business  dur_Lifestyle  \
# 1          19.273367          0.0      35.316076      4.000000      60.666667
# 2           0.000000          0.0       0.000000     24.285714       0.000000
#
#    dur_Transportation  dur_Weather  dur_Sports  dur_Browser  \
# 1           55.469027          0.0  124.447371    72.502856
# 2           74.587645          0.0    0.000000    95.829110
#
#    dur_Health...Fitness  dur_Media...Video  dur_Social  dur_Comics
# 1            125.382997              140.0    0.000000         0.0
# 2              0.000000                0.0   82.581954         0.0

# %%
df_categories_dur_mean = df_categories_dur.mean(axis = 0, skipna = True)
df_categories_dur_mean
# Out:
# mydatatest.avg_duration_calls    103.729555
# dur_Tools                         16.541400
# dur_Finance                       11.371972
# dur_Games                        153.330079
# dur_Entertainment                 94.005113
# dur_Productivity                  23.472882
# dur_Personalization                4.348049
# dur_News...Magazines              36.655824
# dur_Unknown                        4.363831
# dur_Photography                   23.917920
# dur_Shopping                      33.203324
# dur_Communication                 31.276671
# dur_Books...Reference             31.238918
# dur_Travel...Local                55.909233
# dur_Music...Audio                 15.367923
# dur_Medical                        2.147814
# dur_Education                     32.851426
# dur_Business                      36.405302
# dur_Lifestyle                     24.790996
# dur_Transportation                39.471704
# dur_Weather                       10.653809
# dur_Sports                        18.179038
# dur_Browser                       72.152846
# dur_Health...Fitness              20.519298
# dur_Media...Video                 38.645176
# dur_Social                        50.517572
# dur_Comics                         5.332793
# dtype: float64

# %%
labels = ['Calls','Tools','Finance','Games','Entertainment','Productivity',
          'Personalization','News & Magazines','Unknown','Photography','Shopping',
          'Communication','Books & Reference','Travel & Local','Music & Audio',
          'Medical','Education','Business','Lifestyle','Transportation','Weather','Sports',
          'Browser','Health & Fitness', 'Media & Video', 'Social', 'Comics']

ax = sns.barplot(x=df_categories_dur_mean.index, y=df_categories_dur_mean.values)
ax.set_xticklabels(rotation=90, labels=labels)
plt.xlabel("Application category")
plt.ylabel("Average duration per use")

#fig = ax.get_figure()
#plt.savefig('figures/average-duration-per-use-by-category', dpi=200)

plt.show(ax)

# %%
print(df_categories_freq_mean.shape[0] + df_categories_dur_mean.shape[0] + 1) # 1 is the fluidIQ
# Out:
# 55

# %%
df_dependent_var = df[['Emotional.Stability..N.','Extraversion..E.','Openness..O.',
                                    'Conscientiousness..C.','Agreeableness..A.']].copy()
personality_traits_labels = ['Emotional Stability','Extraversion','Openness', 'Conscientiousness','Agreeableness']

df_dependent_var.columns = personality_traits_labels

df_dependent_var.describe()
# Out:
#        Emotional Stability  Extraversion    Openness  Conscientiousness  \
# count           137.000000    137.000000  137.000000         137.000000
# mean             -0.042369      0.028110    0.014118           0.078236
# std               0.704431      0.738225    0.719639           0.771432
# min              -1.995500     -1.976000   -1.841000          -1.625900
# 25%              -0.420000     -0.462800   -0.496600          -0.433400
# 50%              -0.047500     -0.000700   -0.112800           0.059000
# 75%               0.430300      0.486100    0.441600           0.601800
# max               2.520100      1.876400    2.117600           1.814300
#
#        Agreeableness
# count     137.000000
# mean       -0.155520
# std         0.751646
# min        -2.109900
# 25%        -0.632900
# 50%        -0.189000
# 75%         0.282200
# max         1.800900

# %%
plt.figure(figsize=(5,1.5))
sns.heatmap(df_dependent_var.corr(), annot=True)

# %%
# More open individuals tend to be more extroverted - corr 0.586
df_dependent_var.corr()
# Out:
#                      Emotional Stability  Extraversion  Openness  \
# Emotional Stability             1.000000      0.466411  0.330481
# Extraversion                    0.466411      1.000000  0.586026
# Openness                        0.330481      0.586026  1.000000
# Conscientiousness               0.337933      0.255220  0.294319
# Agreeableness                   0.281577      0.381179  0.423569
#
#                      Conscientiousness  Agreeableness
# Emotional Stability           0.337933       0.281577
# Extraversion                  0.255220       0.381179
# Openness                      0.294319       0.423569
# Conscientiousness             1.000000       0.170422
# Agreeableness                 0.170422       1.000000

# %%
ax = sns.pairplot(df_dependent_var)
plt.show(ax)

# %% [markdown]
# ## Distribute into binary classes (0 or 1) for each trait
#
# The median (50th percentile) is used to split the data between low and high tendencies of each personality trait (e.g., extraversion)
#
# + Low: 0
# + High: 1

# %%
# Eliminate the unnecessary columns 
df_binary = df.copy()
df_binary.drop(['Carefreeness..N1.','Equanimity..N2.','Positive.mood..N3.','Self.consciousness..N4.',
        'Self.control..N5.','Emot..robustness..N6.',
        'Friendliness..E1.','Sociableness..E2.', 'Assertiveness..E3.','Dynamism..E4.','Adventurousness...E5.',
        'Cheerfulness..E6.','Openn..to.imagin...O1.', 'Openn..to.aesth...O2.','Openn..to.feel...O3.',
        'Openn..to.actions..O4.', 'Openn..to.ideas..O5.', 'Openn..to.val..norm...O6.', 
        'Competence..C1.', 'Love.of.order..C2.', 'Sense.of.duty..C3.', 'Ambition..C4.', 'Discipline..C5.', 'Caution..C6.',
        'Willingness.to.trust..A1.', 'Genuineness..A2.', 'Helpfulness..A3.', 'Obligingness..A4.', 
        'Modesty..A5.', 'Good.naturedness..A6.'], axis=1, inplace=True)

df_binary.rename(columns={'Emotional.Stability..N.':'Emotional Stability',
                          'Extraversion..E.':'Extraversion',
                          'Openness..O.':'Openness',
                          'Conscientiousness..C.':'Conscientiousness',
                          'Agreeableness..A.':'Agreeableness'}, inplace=True)

df_binary.head(5)
# Out:
#       ID  Gender  Age  Education_lev  fluidIQ  Emotional Stability  \
# 1  11304       1   23              4   0.7251              -0.9334
# 2  11491       1   21              4   0.9921               1.1622
# 3  12552       2   22              5   0.5541              -1.6827
# 4  13275       2   34              5   0.7387              -0.9873
# 5  13604       2   23              4   0.9785               0.1927
#
#    Extraversion  Openness  Conscientiousness  Agreeableness  freq_calls  \
# 1       -1.0278   -1.0703            -0.8548        -1.4482         120
# 2       -1.1607    0.1221             1.0258        -2.1099          98
# 3       -0.2877    0.1810            -1.1241        -0.1796         226
# 4       -0.8691   -0.4643            -1.4071        -0.8839          89
# 5        0.3674   -0.3404             0.1243        -0.6329         244
#
#    freq_Tools  freq_Finance  freq_Games  freq_Entertainment  \
# 1         414             0          40                  51
# 2         239             3           0                  21
# 3         135             0         347                   6
# 4         157             0           0                  41
# 5         140             0         164                  20
#
#    freq_Productivity  freq_Personalization  freq_News...Magazines  \
# 1                553                     0                      8
# 2                 88                     0                      4
# 3                 75                     0                      9
# 4                 75                     2                      4
# 5                140                     1                      0
#
#    freq_Unknown  freq_Photography  freq_Shopping  freq_Communication  \
# 1            31               260             52                1930
# 2            42               113             23                3430
# 3             6                40             19                1068
# 4          3625               102              0                3140
# 5          3284               266              0                2153
#
#    freq_Books...Reference  freq_Travel...Local  freq_Music...Audio  \
# 1                       3                  128                 113
# 2                       5                   19                   4
# 3                      12                   20                   2
# 4                     256                  108                  21
# 5                      14                  141                  13
#
#    freq_Medical  freq_Education  freq_Business  freq_Lifestyle  \
# 1             0              11              1               7
# 2             0               0              7               0
# 3             0              69              3               0
# 4             0               0              9               0
# 5             0               0              0               0
#
#    freq_Transportation  freq_Weather  freq_Sports  freq_Browser  \
# 1                  153             0          184           231
# 2                   34             0            0           187
# 3                   47             0            0           101
# 4                    3           108            0           263
# 5                    6            72            0           363
#
#    freq_Health...Fitness  freq_Media...Video  freq_Social  freq_Comics  \
# 1                    176                   1            8            0
# 2                      0                   1          211            0
# 3                      0                   0          277            0
# 4                     53                   4          118            0
# 5                      0                  10           15            0
#
#    mydatatest.avg_duration_calls  dur_Tools  dur_Finance   dur_Games  \
# 1                      80.508333  19.989234          0.0  474.149741
# 2                     176.214286  21.201236         77.0    0.000000
# 3                      84.902655  27.019119          0.0  178.964202
# 4                      35.314607  20.677723          0.0    0.000000
# 5                      98.163934   8.812732          0.0   43.500911
#
#    dur_Entertainment  dur_Productivity  dur_Personalization  \
# 1          66.142812         27.299807                  0.0
# 2         292.695366         29.823646                  0.0
# 3           0.000000         32.312866                  0.0
# 4          84.173028         31.069522                 99.0
# 5           3.621455         14.409825                  6.0
#
#    dur_News...Magazines  dur_Unknown  dur_Photography  dur_Shopping  \
# 1             63.482948     5.594866        22.306456     62.541808
# 2              0.000000     2.149066        16.753147     90.804380
# 3             95.700334     5.062647        38.577362     39.389153
# 4              0.000000     3.227029        17.030655      0.000000
# 5              0.000000     2.502265        11.132798      0.000000
#
#    dur_Communication  dur_Books...Reference  dur_Travel...Local  \
# 1          60.222363             102.000000           66.640780
# 2          42.197411              52.000000           53.702947
# 3          25.361692              35.660060          149.456141
# 4          41.059489              30.193285           42.857908
# 5          26.968565              67.712688           48.223207
#
#    dur_Music...Audio  dur_Medical  dur_Education  dur_Business  dur_Lifestyle  \
# 1          19.273367          0.0      35.316076      4.000000      60.666667
# 2           0.000000          0.0       0.000000     24.285714       0.000000
# 3          20.000000          0.0     239.753781      3.666667       0.000000
# 4          15.253427          0.0       0.000000     11.405742       0.000000
# 5           2.245006          0.0       0.000000      0.000000       0.000000
#
#    dur_Transportation  dur_Weather  dur_Sports  dur_Browser  \
# 1           55.469027     0.000000  124.447371    72.502856
# 2           74.587645     0.000000    0.000000    95.829110
# 3           65.977454     0.000000    0.000000    86.099052
# 4            2.000000    28.180582    0.000000    50.146309
# 5           77.333333     3.812671    0.000000    30.335529
#
#    dur_Health...Fitness  dur_Media...Video  dur_Social  dur_Comics
# 1            125.382997              140.0    0.000000         0.0
# 2              0.000000                0.0   82.581954         0.0
# 3              0.000000                0.0   78.253432         0.0
# 4             37.600068                0.0   63.630655         0.0
# 5              0.000000                9.0   16.400009         0.0

# %%
# Calculate the median for each personality trait
df_median = df_binary.loc[:,'Emotional Stability':'Agreeableness'].copy()
df_median = df_median.median()

df_median
# Out:
# Emotional Stability   -0.0475
# Extraversion          -0.0007
# Openness              -0.1128
# Conscientiousness      0.0590
# Agreeableness         -0.1890
# dtype: float64

# %%
# Renumerate the values below the median with 0 and above with 1
# Run only once 
for column_name in ['Emotional Stability','Extraversion','Openness', 'Conscientiousness','Agreeableness']:
    df_binary.loc[df_binary[column_name] >= df_median[column_name], column_name] = 1
    df_binary.loc[df_binary[column_name] < df_median[column_name], column_name] = 0
    df_binary[column_name] = df_binary[column_name].astype(int)

print(df_binary['Extraversion'].value_counts())

df_binary.head(2)
# Out:
# 1    69
# 0    68
# Name: Extraversion, dtype: int64
#       ID  Gender  Age  Education_lev  fluidIQ  Emotional Stability  \
# 1  11304       1   23              4   0.7251                    0
# 2  11491       1   21              4   0.9921                    1
#
#    Extraversion  Openness  Conscientiousness  Agreeableness  freq_calls  \
# 1             0         0                  0              0         120
# 2             0         1                  1              0          98
#
#    freq_Tools  freq_Finance  freq_Games  freq_Entertainment  \
# 1         414             0          40                  51
# 2         239             3           0                  21
#
#    freq_Productivity  freq_Personalization  freq_News...Magazines  \
# 1                553                     0                      8
# 2                 88                     0                      4
#
#    freq_Unknown  freq_Photography  freq_Shopping  freq_Communication  \
# 1            31               260             52                1930
# 2            42               113             23                3430
#
#    freq_Books...Reference  freq_Travel...Local  freq_Music...Audio  \
# 1                       3                  128                 113
# 2                       5                   19                   4
#
#    freq_Medical  freq_Education  freq_Business  freq_Lifestyle  \
# 1             0              11              1               7
# 2             0               0              7               0
#
#    freq_Transportation  freq_Weather  freq_Sports  freq_Browser  \
# 1                  153             0          184           231
# 2                   34             0            0           187
#
#    freq_Health...Fitness  freq_Media...Video  freq_Social  freq_Comics  \
# 1                    176                   1            8            0
# 2                      0                   1          211            0
#
#    mydatatest.avg_duration_calls  dur_Tools  dur_Finance   dur_Games  \
# 1                      80.508333  19.989234          0.0  474.149741
# 2                     176.214286  21.201236         77.0    0.000000
#
#    dur_Entertainment  dur_Productivity  dur_Personalization  \
# 1          66.142812         27.299807                  0.0
# 2         292.695366         29.823646                  0.0
#
#    dur_News...Magazines  dur_Unknown  dur_Photography  dur_Shopping  \
# 1             63.482948     5.594866        22.306456     62.541808
# 2              0.000000     2.149066        16.753147     90.804380
#
#    dur_Communication  dur_Books...Reference  dur_Travel...Local  \
# 1          60.222363                  102.0           66.640780
# 2          42.197411                   52.0           53.702947
#
#    dur_Music...Audio  dur_Medical  dur_Education  dur_Business  dur_Lifestyle  \
# 1          19.273367          0.0      35.316076      4.000000      60.666667
# 2           0.000000          0.0       0.000000     24.285714       0.000000
#
#    dur_Transportation  dur_Weather  dur_Sports  dur_Browser  \
# 1           55.469027          0.0  124.447371    72.502856
# 2           74.587645          0.0    0.000000    95.829110
#
#    dur_Health...Fitness  dur_Media...Video  dur_Social  dur_Comics
# 1            125.382997              140.0    0.000000         0.0
# 2              0.000000                0.0   82.581954         0.0

# %% [markdown]
# ## Machine Learning

# %%
# Required dependencies 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import sklearn.ensemble
import sklearn.preprocessing

from sklearn.metrics import accuracy_score

# %% [markdown]
# #### Extroversion Personality Trait

# %%
# Copy dataframe
data = df_binary.copy()

# Extraversion
trait = 'Extraversion'

data.drop(columns=['ID','Emotional Stability','Openness','Conscientiousness','Agreeableness'], inplace=True)

# Move target trait to the end
extraversion_column = data.pop(trait) # remove column
data[trait]= extraversion_column # append to the end


for index in range(0,data.shape[1]-1):
    data.iloc[:,[index]] = data.iloc[:, [index]].astype(float)

# Get feature columns name
feature_names = data.columns.values
feature_names = np.delete(feature_names,58) # Remove last column (i.e., target)

data.to_csv('data_treated/ml_extroverted_trait.csv')

    
print(data.shape)    
data.head(2)
# Out:
# (137, 59)
#    Gender   Age  Education_lev  fluidIQ  freq_calls  freq_Tools  freq_Finance  \
# 1     1.0  23.0            4.0   0.7251       120.0       414.0           0.0
# 2     1.0  21.0            4.0   0.9921        98.0       239.0           3.0
#
#    freq_Games  freq_Entertainment  freq_Productivity  freq_Personalization  \
# 1        40.0                51.0              553.0                   0.0
# 2         0.0                21.0               88.0                   0.0
#
#    freq_News...Magazines  freq_Unknown  freq_Photography  freq_Shopping  \
# 1                    8.0          31.0             260.0           52.0
# 2                    4.0          42.0             113.0           23.0
#
#    freq_Communication  freq_Books...Reference  freq_Travel...Local  \
# 1              1930.0                     3.0                128.0
# 2              3430.0                     5.0                 19.0
#
#    freq_Music...Audio  freq_Medical  freq_Education  freq_Business  \
# 1               113.0           0.0            11.0            1.0
# 2                 4.0           0.0             0.0            7.0
#
#    freq_Lifestyle  freq_Transportation  freq_Weather  freq_Sports  \
# 1             7.0                153.0           0.0        184.0
# 2             0.0                 34.0           0.0          0.0
#
#    freq_Browser  freq_Health...Fitness  freq_Media...Video  freq_Social  \
# 1         231.0                  176.0                 1.0          8.0
# 2         187.0                    0.0                 1.0        211.0
#
#    freq_Comics  mydatatest.avg_duration_calls  dur_Tools  dur_Finance  \
# 1          0.0                      80.508333  19.989234          0.0
# 2          0.0                     176.214286  21.201236         77.0
#
#     dur_Games  dur_Entertainment  dur_Productivity  dur_Personalization  \
# 1  474.149741          66.142812         27.299807                  0.0
# 2    0.000000         292.695366         29.823646                  0.0
#
#    dur_News...Magazines  dur_Unknown  dur_Photography  dur_Shopping  \
# 1             63.482948     5.594866        22.306456     62.541808
# 2              0.000000     2.149066        16.753147     90.804380
#
#    dur_Communication  dur_Books...Reference  dur_Travel...Local  \
# 1          60.222363                  102.0           66.640780
# 2          42.197411                   52.0           53.702947
#
#    dur_Music...Audio  dur_Medical  dur_Education  dur_Business  dur_Lifestyle  \
# 1          19.273367          0.0      35.316076      4.000000      60.666667
# 2           0.000000          0.0       0.000000     24.285714       0.000000
#
#    dur_Transportation  dur_Weather  dur_Sports  dur_Browser  \
# 1           55.469027          0.0  124.447371    72.502856
# 2           74.587645          0.0    0.000000    95.829110
#
#    dur_Health...Fitness  dur_Media...Video  dur_Social  dur_Comics  \
# 1            125.382997              140.0    0.000000         0.0
# 2              0.000000                0.0   82.581954         0.0
#
#    Extraversion
# 1             0
# 2             0

# %%
# Convert to numpy array
data = data.values

# Get last index (target, which is the trait)
target_index = data.shape[1] - 1 

data.shape
# Out:
# (137, 59)

# %%
y = data[:,target_index]
le = sklearn.preprocessing.LabelEncoder()
le.fit(y)
labels = le.transform(y) 
class_names = le.classes_ # array([0., 1.])
data = data[:,:-1]

categorical_features = [0, 2] # Gender and Education_lev, remaining ones are numerical

categorical_names = {}
for feature in categorical_features:
    le = sklearn.preprocessing.LabelEncoder()
    le.fit(data[:, feature])
    data[:, feature] = le.transform(data[:, feature])
    categorical_names[feature] = le.classes_

data = data.astype(float)

encoder = sklearn.preprocessing.OneHotEncoder(categorical_features=categorical_features)

# %%
# Split the data into training and test sets 

np.random.seed(1)
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.25)

encoder.fit(data)
encoded_train = encoder.transform(X_train)

print(X_train.shape)
print(X_test.shape)
# Out:
# (102, 58)
# (35, 58)
# /usr/local/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
# The y_train and y_test contain each of the personality traits

# %%
# ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
# The default is 100 max interations, we changed to 800 
lr_clf_es = LogisticRegression(random_state=0, C=0.001,max_iter=800, solver='lbfgs', multi_class='multinomial')
#lr_clf_es = sklearn.ensemble.RandomForestClassifier(n_estimators=500)
lr_clf_es = lr_clf_es.fit(X_train,y_train)

# Test the model
y_pred = lr_clf_es.predict(X_test)

# Get the accuracy
lr_clf_es_accuracy = accuracy_score(y_test, y_pred)

print('Accuracy:', lr_clf_es_accuracy)

# LIME requires class probabilities in case of classification example
# Get probability estimates.
#lr_clf_es_proba = lr_clf_es.predict_proba
lr_clf_es_proba = lambda x: lr_clf_es.predict_proba(x).astype(float)
# Out:
# Accuracy: 0.4857142857142857

# %%
# LIME works for different types of data such as text, images, categorical, numerical, ...
import lime
import lime.lime_tabular

# Create the explainer
explainer = lime.lime_tabular.LimeTabularExplainer(
    training_data=X_train, # convert from pandas DataFrame to numpy 2d array
    mode='classification',
    feature_names=feature_names, # All columns name
    categorical_features=categorical_features, # Index of categorical features (int)
    categorical_names=categorical_names, 
    # class_names=class_names, # classes (0 and 1)
    class_names=['low', 'high'],
    discretize_continuous=True
)

# Explain an instance
np.random.seed(1)
i = 0
exp = explainer.explain_instance(
    X_test[i],
    lr_clf_es_proba, 
    num_features=10,
    num_samples=10000, # size of the neighborhood to learn the linear model,
    distance_metric='euclidean',
    model_regressor=None
)

exp.show_in_notebook(show_table=True, show_all=False)
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %%
X_test[i]
# Out:
# array([1.00000000e+00, 6.00000000e+00, 3.00000000e+00, 4.34600000e-01,
#        1.35000000e+02, 1.83000000e+02, 7.00000000e+00, 0.00000000e+00,
#        8.00000000e+00, 1.25000000e+02, 0.00000000e+00, 6.00000000e+00,
#        8.10000000e+01, 4.20000000e+01, 0.00000000e+00, 1.13700000e+03,
#        0.00000000e+00, 5.00000000e+01, 6.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.60000000e+01, 6.30000000e+01,
#        0.00000000e+00, 0.00000000e+00, 2.33000000e+02, 0.00000000e+00,
#        0.00000000e+00, 4.33000000e+02, 0.00000000e+00, 1.95851852e+01,
#        1.66576808e+01, 1.10300371e+02, 0.00000000e+00, 2.20000000e+01,
#        2.08495779e+01, 0.00000000e+00, 3.16333704e+00, 4.72588015e+00,
#        1.84919129e+01, 0.00000000e+00, 2.95624103e+01, 0.00000000e+00,
#        6.17121875e+01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 4.58595486e+01, 6.39156111e+01, 0.00000000e+00,
#        0.00000000e+00, 1.04860532e+02, 0.00000000e+00, 0.00000000e+00,
#        1.01366151e+02, 0.00000000e+00])

# %%
X_train.values.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-7f5844dc541f> in <module>
# ----> 1 X_train.values.shape
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
feature_names = data.columns.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-334a67c5bac0> in <module>
# ----> 1 feature_names = data.columns.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
X_test.values.shape

# %%
X_test['Age'].values

# %%
lr_clf_es_proba

# %%
lr_clf_es.predict_proba

# %%
y_test[trait].shape

# %%
y_pred.shape

# %%
X_test['freq_Communication'].shape

# %%
len(X_test.values)

# %%
lr_clf_es_proba

# %%
X_train.columns.values.shape

# %%
lr_clf_es_proba

# %%
lr_clf_es_proba

# %%
X_test[i].shape

# %%
X_test[1].reshape(-1,1)
